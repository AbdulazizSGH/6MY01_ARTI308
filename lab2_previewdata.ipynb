# %%
import pandas as pd

data=pd.read_csv("ai_impact_jobs_2010_2025.csv", nrows=3, na_values=["N/A"])

print(data)
# Out:
#                                  job_id  posting_year country         region  \
# 0  836b4774-702e-49ef-93d3-2f255ce1e910          2018  Brazil  South America
# 1  43699e93-7b15-4728-a4c6-9e41ff438a25          2015     UAE    Middle East
# 2  fc9d1854-3cbf-4bab-90df-77304dfc59df          2016   Nepal     South Asia
#
#         city          company_name company_size   industry        job_title  \
# 0     London  NextGen Technologies        Small  Education   Policy Analyst
# 1  Singapore      Future Solutions       Medium     Energy   Data Scientist
# 2     Sydney      Future Analytics      Startup    Finance  Product Manager
#
#   seniority_level  ...  ai_intensity_score  \
# 0            Lead  ...                0.81
# 1       Executive  ...                0.04
# 2          Junior  ...                0.15
#
#                                          core_skills               ai_skills  \
# 0    Research, Project Management, Business Analysis  reinforcement learning
# ...
